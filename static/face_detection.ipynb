# %%
from functions import *
from keras.models import load_model
import pandas as pd
import numpy as np
import cv2
import pprint as pp
import datetime as dt
# Out:
# C:\Users\Josh\Anaconda3\envs\PythonData\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
emotion_model_path = 'models/fer2013_mini_XCEPTION.119-0.65.hdf5'
cascade_model_path = 'models/haarcascade_frontalface_default.xml'

emotion_classifier = load_model(emotion_model_path)
face_classifier = cv2.CascadeClassifier(cascade_model_path)

emotion_target_size = emotion_classifier.input_shape[1:3]

emotion_labels = {
    0: 'angry',
    1: 'disgust',
    2: 'fear',
    3: 'happy',
    4: 'sad',
    5: 'surprise',
    6: 'neutral'
}
# Out:
# C:\Users\Josh\Anaconda3\envs\PythonData\lib\site-packages\keras\engine\saving.py:327: UserWarning: Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
#   warnings.warn('Error in loading the saved optimizer '

# %%
cv2.namedWindow('frame')
video = cv2.VideoCapture(0)

emotion_offsets = (20, 40)

emotion_window = []

analysis = []


while(True):
    # Capture frame-by-frame
    ret, frame = video.read()

    # Our operations on the frame come here
    gray_image = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    rgb_image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    
    
    faces = face_classifier.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30), flags=cv2.CASCADE_SCALE_IMAGE)
    
    for face_coords in faces:
        
        x1, x2, y1, y2 = apply_offsets(face_coords, emotion_offsets)
        gray_face = gray_image[y1:y2, x1:x2]
        try:
            gray_face = cv2.resize(gray_face, (emotion_target_size))
        except:
            continue
            
        gray_face = preprocess_input(gray_face, True)
        gray_face = np.expand_dims(gray_face, 0)
        gray_face = np.expand_dims(gray_face, -1)
        emotion_prediction = emotion_classifier.predict(gray_face)
        emotion_probability = np.max(emotion_prediction)
        emotion_label_arg = np.argmax(emotion_prediction)
        emotion_text = emotion_labels[emotion_label_arg]
        emotion_window.append(emotion_text)

        if emotion_text == 'angry':
            color = [255, 0, 0]
            now = str(dt.datetime.now())
            analysis.append({
                "Time": now,
                "Emotion": 'angry'     
            })
            
        elif emotion_text == 'disgust':
            color = [128, 0, 128]
            now = str(dt.datetime.now())
            analysis.append({
                "Time": now,
                "Emotion": 'disgust'     
            })
            
        elif emotion_text == 'fear':
            color = [255, 255, 0]
            now = str(dt.datetime.now())
            analysis.append({
                "Time": now,
                "Emotion": 'fear'     
            })
            
        elif emotion_text == 'happy':
            color = [255, 192, 203]
            now = str(dt.datetime.now())
            analysis.append({
                "Time": now,
                "Emotion": 'happy'     
            })
            
        elif emotion_text == 'sad':
            color = [0, 0, 255]
            now = str(dt.datetime.now())
            analysis.append({
                "Time": now,
                "Emotion": 'sad'     
            })
            
        elif emotion_text == 'surprise':
            color = [0, 0, 0]
            now = str(dt.datetime.now())
            analysis.append({
                "Time": now,
                "Emotion": 'surprise'     
            })
            
        else:
            color = [255, 255, 255]
            now = str(dt.datetime.now())
            analysis.append({
                "Time": now,
                "Emotion": 'neutral'     
            })

        draw_bounding_box(face_coords, rgb_image, color)
        draw_text(face_coords, rgb_image, emotion_text, color)
    
    # Display the resulting frame
    frame = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2BGR)
    cv2.imshow('frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5
 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:41.117591', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:41.191393', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:41.196380', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:41.265196', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:41.330022', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:41.395846', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:41.472641', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:41.547441', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:41.623238', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:41.699035', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:41.762864', 'Emotion': 'surprise'},
#  {'Time': '2019-01-26 19:59:41.828688', 'Emotion': 'surprise'},
#  {'Time': '2019-01-26 19:59:41.893515', 'Emotion': 'fear'},
#  {'Time': '2019-01-26 19:59:41.898502', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:41.963328', 'Emotion': 'fear'},
#  {'Time': '2019-01-26 19:59:42.029152', 'Emotion': 'fear'},
#  {'Time': '2019-01-26 19:59:42.095973', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:42.170773', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:42.175760', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:42.243578', 'Emotion': 'fear'},
#  {'Time': '2019-01-26 19:59:42.309402', 'Emotion': 'fear'},
#  {'Time': '2019-01-26 19:59:42.314389', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:42.381210', 'Emotion': 'fear'},
#  {'Time': '2019-01-26 19:59:42.386197', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:42.451024', 'Emotion': 'fear'},
#  {'Time': '2019-01-26 19:59:42.514853', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:42.578682', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:42.644506', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:42.713322', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:42.779146', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:42.842975', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:42.907802', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:42.972628', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:43.038452', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:43.115247', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:43.178078', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:43.242905', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:43.247892', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:43.323689', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:43.328676', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:43.391508', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:43.454339', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:43.531134', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:43.595961', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:43.659790', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:43.730601', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:43.795427', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:43.860254', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:43.925080', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:43.989907', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:44.057725', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:44.124547', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:44.191368', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:44.262179', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:44.330994', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:44.399810', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:44.404797', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:44.472615', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:44.536445', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:44.601272', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:44.606259', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:44.611245', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:44.674077', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:44.737906', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:44.805725', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:44.866562', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:44.936376', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:45.003196', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:45.069020', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:45.134844', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:45.199671', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:45.266492', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:45.272476', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:45.348273', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:45.424071', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:45.430055', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:45.494881', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:45.563697', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:45.569681', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:45.639494', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:45.710305', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:45.716293', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:45.797072', 'Emotion': 'fear'},
#  {'Time': '2019-01-26 19:59:45.884837', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:45.975595', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:45.980582', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:46.046406', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:46.117216', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:46.185035', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:46.256843', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:46.338624', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:46.416416', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:46.492214', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:46.568010', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:46.642810', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:46.648795', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:46.743541', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:46.829312', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:46.913087', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:46.995866', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:47.071663', 'Emotion': 'neutral'}]

# %%
print(analysis[0])
print(analysis[0]['Emotion'])
# Out:
# {'Time': '2019-01-26 19:59:27.530935', 'Emotion': 'neutral'}
# neutral

# %%
for x in range(len(analysis)):
    if analysis[0]['Emotion'] == 'neutral':
        analysis.remove(analysis[x])
    else:
        next

# %%
range(len(analysis))
# Out:
# range(0, 342)

# %%
analysis
# Out:
# [{'Time': '2019-01-26 19:59:27.535922', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:27.620695', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:27.684524', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:27.747356', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:27.824151', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:27.885985', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:27.953804', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:28.035584', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:28.118363', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:28.203137', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:28.267964', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:28.331793', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:28.394624', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:28.399612', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:28.464438', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:28.469425', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:28.534251', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:28.539238', 'Emotion': 'surprise'},
#  {'Time': '2019-01-26 19:59:28.602070', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:28.666897', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:28.730725', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:28.792560', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:28.857387', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:28.920218', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:28.984048', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:29.048875', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:29.111707', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:29.174539', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:29.180523', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:29.262304', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:29.337104', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:29.411903', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:29.417887', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:29.487701', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:29.560506', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:29.629322', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:29.702127', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:29.707114', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:29.779919', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:29.786900', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:29.877658', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:29.885636', 'Emotion': 'surprise'},
#  {'Time': '2019-01-26 19:59:29.959439', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:30.023268', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:30.086100', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:30.092084', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:30.161897', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:30.167881', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:30.227721', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:30.305513', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:30.379316', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:30.455113', 'Emotion': 'angry'},
#  {'Time': '2019-01-26 19:59:30.518942', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:30.585763', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:30.659566', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:30.726387', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:30.731374', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:30.797197', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:30.859032', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:30.924856', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:30.991678', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:31.054509', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:31.118339', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:31.181171', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:31.186157', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:31.250984', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:31.256968', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:31.320798', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:31.325784', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:31.393603', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:31.459426', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:31.524253', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:31.529240', 'Emotion': 'surprise'},
#  {'Time': '2019-01-26 19:59:31.597058', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:31.663880', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:31.729703', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:31.795527', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:31.866338', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:31.935154', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:32.003969', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:32.072785', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:32.138610', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:32.202439', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:32.272252', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:32.337079', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:32.406892', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:32.470721', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:32.539537', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:32.607356', 'Emotion': 'happy'},
#  {'Time': '2019-01-26 19:59:32.675175', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:32.742993', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:32.747980', 'Emotion': 'surprise'},
#  {'Time': '2019-01-26 19:59:32.815798', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:32.820784', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:32.885611', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:32.948443', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:33.020251', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:33.086075', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:33.091062', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:33.154891', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:33.160875', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:33.226699', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:33.298507', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:33.368320', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:33.433146', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:33.498971', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:33.503958', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:33.567786', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:33.630619', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:33.694448', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:33.761269', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:33.766256', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59:33.832080', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:33.897903', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:33.968714', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:34.032543', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:34.105348', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:34.171172', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:34.238991', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:34.301823', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:34.366650', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:34.432473', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:34.494308', 'Emotion': 'neutral'},
#  {'Time': '2019-01-26 19:59:34.499294', 'Emotion': 'sad'},
#  {'Time': '2019-01-26 19:59